# %%
import os
# !rm -r sample_data

#clone repo AttnGAN
# !git clone https://github.com/taoxugit/AttnGAN.git

#Dwonload files config.py, utils.py, datasets.py, pretrain_DAMSM.py
# !git clone https://github.com/ammarnasr/CUB-Attn-GAN.git

#Move Models text and image encoder to their /content/
# !mv /content/CUB-Attn-GAN/theModel/text_encoder272.pth /content/
# !mv /content/CUB-Attn-GAN/theModel/image_encoder272.pth /content/

#Move code files to their Locations
# !mv /content/CUB-Attn-GAN/theCode/bird.yml /content/AttnGAN/code/cfg/DAMSM/
# !mv /content/CUB-Attn-GAN/theCode/config.py /content/AttnGAN/code/miscc/
# !mv /content/CUB-Attn-GAN/theCode/utils.py /content/AttnGAN/code/miscc/
# !mv /content/CUB-Attn-GAN/theCode/losses.py /content/AttnGAN/code/miscc/
# !mv /content/CUB-Attn-GAN/theCode/pretrain_DAMSM.py /content/AttnGAN/code/
# !mv /content/CUB-Attn-GAN/theCode/datasets.py /content/AttnGAN/code/

#Remove the Repo
# !rm -r /content/CUB-Attn-GAN/

#Changing Working dirctory to data
os.chdir('/content/AttnGAN/data/')
print(os.getcwd())
print("Check Marker in first Comment of every file for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads birds.zip (6.19M) , Extract it , and remove unnesscery files
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1O_LtUP9sch09QH3s_EBAgLEctBQ5JBSJ' -O birds.zip
# !unzip -q birds.zip
# !rm birds.zip
# !rm -r __MACOSX/

#Changing Working dirctory to birds
os.chdir('/content/AttnGAN/data/birds/')
print(os.getcwd())
print("Check birds.zip (6.19M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Download CUB_200_2011.tgz (1.07G), , Extract it , and remove unnesscery files
# !wget http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz
# !tar zxf  CUB_200_2011.tgz
# !rm CUB_200_2011.tgz

#Changing Working dirctory to DAMSMencoders
os.chdir('/content/AttnGAN/DAMSMencoders/')
print(os.getcwd())
print("Check CUB_200_2011.tgz (1.07G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Download birds.zip (87.15M), , Extract it , and remove unnesscery files
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1GNUKjVeyWYBJ8hEU-yrfYQpDOkxEyP3V' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1GNUKjVeyWYBJ8hEU-yrfYQpDOkxEyP3V" -O birds.zip && rm -rf /tmp/cookies.txt
# !unzip -q birds.zip
# !rm birds.zip

#Changing Working dirctory to models
os.chdir('/content/AttnGAN/models/')
print(os.getcwd())
print("Check birds.zip (87.15M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Download bird_AttnDCGAN2.pth (25.46M).
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=19TG0JUoXurxsmZLaJ82Yo6O0UJ6aDBpg' -O bird_AttnDCGAN2.pth

#Changing Working dirctory to code
os.chdir('/content/AttnGAN/code/')
print(os.getcwd())
print("Check bird_AttnDCGAN2.pth (25.46M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Download Pillow.rar (251.75K), , Extract it , and remove unnesscery files
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Wr3lQajG7m6Bi3rYFTJb6mwE_d8su111' -O Pillow.rar
# !unrar x  Pillow.rar
# !rm Pillow.rar

#The command : !python pretrain_DAMSM.py --cfg cfg/DAMSM/bird.yml --gpu 0

# %%
#Changing Working dirctory to birds
os.chdir('/content/AttnGAN/data/birds/')
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1hbzc_P1FuxMkcabkgn9ZKinBwW683j45' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1hbzc_P1FuxMkcabkgn9ZKinBwW683j45" -O CUB_200_2011.tgz && rm -rf /tmp/cookies.txt
# !tar zxf  CUB_200_2011.tgz
# !rm CUB_200_2011.tgz

# %%
os.chdir('/content/AttnGAN/code/')
# !python pretrain_DAMSM.py --cfg cfg/DAMSM/bird.yml --gpu 0
# Out:
# Using config:
# {'B_VALIDATION': False,
#  'CONFIG_NAME': 'DAMSM',
#  'CUDA': True,
#  'DATASET_NAME': 'birds',
#  'DATA_DIR': '../data/birds',
#  'GAN': {'B_ATTENTION': True,
#          'B_DCGAN': False,
#          'CONDITION_DIM': 100,
#          'DF_DIM': 64,
#          'GF_DIM': 128,
#          'R_NUM': 2,
#          'Z_DIM': 100},
#  'GPU_ID': 0,
#  'RNN_TYPE': 'LSTM',
#  'TEXT': {'CAPTIONS_PER_IMAGE': 10, 'EMBEDDING_DIM': 256, 'WORDS_NUM': 18},
#  'TRAIN': {'BATCH_SIZE': 48,
#            'B_NET_D': True,
#            'DISCRIMINATOR_LR': 0.0002,
#            'ENCODER_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'MAX_EPOCH': 600,
#            'NET_E': '',
#            'NET_G': '',
#            'RNN_GRAD_CLIP': 0.25,
#            'SMOOTH': {'GAMMA1': 4.0,
#                       'GAMMA2': 5.0,
#                       'GAMMA3': 10.0,
#                       'LAMBDA': 1.0},
#            'SNAPSHOT_INTERVAL': 50},
# ...

# %%
1+1
# Out:
# 2

# %%
Using config:
{'B_VALIDATION': False,
 'CONFIG_NAME': 'DAMSM',
 'CUDA': True,
 'DATASET_NAME': 'birds',
 'DATA_DIR': '../data/birds',
 'GAN': {'B_ATTENTION': True,
         'B_DCGAN': False,
         'CONDITION_DIM': 100,
         'DF_DIM': 64,
         'GF_DIM': 128,
         'R_NUM': 2,
         'Z_DIM': 100},
 'GPU_ID': 0,
 'RNN_TYPE': 'LSTM',
 'TEXT': {'CAPTIONS_PER_IMAGE': 10, 'EMBEDDING_DIM': 256, 'WORDS_NUM': 18},
 'TRAIN': {'BATCH_SIZE': 48,
           'B_NET_D': True,
           'DISCRIMINATOR_LR': 0.0002,
           'ENCODER_LR': 0.0002,
           'FLAG': True,
           'GENERATOR_LR': 0.0002,
           'MAX_EPOCH': 600,
           'NET_E': '',
           'NET_G': '',
           'RNN_GRAD_CLIP': 0.25,
           'SMOOTH': {'GAMMA1': 4.0,
                      'GAMMA2': 5.0,
                      'GAMMA3': 10.0,
                      'LAMBDA': 1.0},
           'SNAPSHOT_INTERVAL': 50},
 'TREE': {'BASE_SIZE': 299, 'BRANCH_NUM': 1},
 'WORKERS': 1}
/usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:211: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
  "please use transforms.Resize instead.")
Total filenames:  11788 001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg
Load filenames from: ../data/birds/train/filenames.pickle (8855)
Load filenames from: ../data/birds/test/filenames.pickle (2933)
Load from:  ../data/birds/captions.pickle
5450 10
Total filenames:  11788 001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg
Load filenames from: ../data/birds/train/filenames.pickle (8855)
Load filenames from: ../data/birds/test/filenames.pickle (2933)
Load from:  ../data/birds/captions.pickle
/usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py:50: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
  "num_layers={}".format(dropout, num_layers))
Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/checkpoints/inception_v3_google-1a9a5a14.pth
100% 104M/104M [00:04<00:00, 26.6MB/s]
Load pretrained model from  https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth
keyword |||||||||||||||||||||||||||||||
Start_epoch :  0
cfg.TRAIN.MAX_EPOCH :  600
keyword |||||||||||||||||||||||||||||||
/usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
  "See the documentation of nn.Upsample for details.".format(mode))
/content/AttnGAN/code/GlobalAttention.py:51: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
  attn = nn.Softmax()(attn)  # Eq. (8)
/content/AttnGAN/code/GlobalAttention.py:60: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
  attn = nn.Softmax()(attn)
pretrain_DAMSM.py:103: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
  cfg.TRAIN.RNN_GRAD_CLIP)
s_total_loss0.item()/UPDATE_INTERVAL :  0.01952077865600586
s_total_loss1.item()/UPDATE_INTERVAL :  0.019744342565536498
w_total_loss0.item()/UPDATE_INTERVAL :  0.02619993209838867
w_total_loss1.item()/UPDATE_INTERVAL :  0.020813372135162354
| epoch   0 |     0/  184 batches | ms/batch 27.14 | s_loss  0.02  0.02 | w_loss  0.03  0.02
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  237.99111771583557
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  393.9648177623749
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   0 | valid loss  7.67  7.56 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  428.6678247451782
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.018557376861572265
s_total_loss1.item()/UPDATE_INTERVAL :  0.01860140323638916
w_total_loss0.item()/UPDATE_INTERVAL :  0.018705178499221802
w_total_loss1.item()/UPDATE_INTERVAL :  0.018595935106277467
| epoch   1 |     0/  184 batches | ms/batch  7.09 | s_loss  0.02  0.02 | w_loss  0.02  0.02
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.81252074241638
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   1 | valid loss  7.07  6.96 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.6348147392273
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.016887296438217164
s_total_loss1.item()/UPDATE_INTERVAL :  0.016834503412246703
w_total_loss0.item()/UPDATE_INTERVAL :  0.01707522749900818
w_total_loss1.item()/UPDATE_INTERVAL :  0.017066882848739626
| epoch   2 |     0/  184 batches | ms/batch  6.86 | s_loss  0.02  0.02 | w_loss  0.02  0.02
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.76998662948608
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   2 | valid loss  6.78  6.56 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.6432707309723
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.016140843629837035
s_total_loss1.item()/UPDATE_INTERVAL :  0.016242762804031374
w_total_loss0.item()/UPDATE_INTERVAL :  0.014853734970092774
w_total_loss1.item()/UPDATE_INTERVAL :  0.015215181112289429
| epoch   3 |     0/  184 batches | ms/batch  6.89 | s_loss  0.02  0.02 | w_loss  0.01  0.02
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.70811891555786
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   3 | valid loss  6.49  6.39 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.69024515151978
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.015222433805465698
s_total_loss1.item()/UPDATE_INTERVAL :  0.015257019996643067
w_total_loss0.item()/UPDATE_INTERVAL :  0.01447611927986145
w_total_loss1.item()/UPDATE_INTERVAL :  0.014581464529037476
| epoch   4 |     0/  184 batches | ms/batch  6.76 | s_loss  0.02  0.02 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.80981612205505
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   4 | valid loss  6.39  6.26 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.60456585884094
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01452118992805481
s_total_loss1.item()/UPDATE_INTERVAL :  0.014550600051879883
w_total_loss0.item()/UPDATE_INTERVAL :  0.013658437728881836
w_total_loss1.item()/UPDATE_INTERVAL :  0.013870691061019897
| epoch   5 |     0/  184 batches | ms/batch  6.71 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.70001697540283
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   5 | valid loss  6.28  6.20 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.4781084060669
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.014857066869735718
s_total_loss1.item()/UPDATE_INTERVAL :  0.014939628839492798
w_total_loss0.item()/UPDATE_INTERVAL :  0.01470273494720459
w_total_loss1.item()/UPDATE_INTERVAL :  0.014573575258255004
| epoch   6 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.49837112426758
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   6 | valid loss  6.17  6.04 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.4991970062256
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.014630626440048217
s_total_loss1.item()/UPDATE_INTERVAL :  0.014679045677185058
w_total_loss0.item()/UPDATE_INTERVAL :  0.014304898977279663
w_total_loss1.item()/UPDATE_INTERVAL :  0.01433613419532776
| epoch   7 |     0/  184 batches | ms/batch  6.95 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.4685366153717
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   7 | valid loss  6.10  5.94 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.5240182876587
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.013709950447082519
s_total_loss1.item()/UPDATE_INTERVAL :  0.013653923273086548
w_total_loss0.item()/UPDATE_INTERVAL :  0.013212342262268067
w_total_loss1.item()/UPDATE_INTERVAL :  0.013211946487426757
| epoch   8 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  238.82309913635254
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  388.6120502948761
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   8 | valid loss  6.06  5.84 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  423.4873402118683
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.013309152126312255
s_total_loss1.item()/UPDATE_INTERVAL :  0.013430334329605102
w_total_loss0.item()/UPDATE_INTERVAL :  0.011690953969955445
w_total_loss1.item()/UPDATE_INTERVAL :  0.012013100385665894
| epoch   9 |     0/  184 batches | ms/batch  6.73 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.67903208732605
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch   9 | valid loss  6.03  5.88 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.60242915153503
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.014789985418319702
s_total_loss1.item()/UPDATE_INTERVAL :  0.01485620141029358
w_total_loss0.item()/UPDATE_INTERVAL :  0.012591686248779297
w_total_loss1.item()/UPDATE_INTERVAL :  0.012684692144393921
| epoch  10 |     0/  184 batches | ms/batch  6.73 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.382981300354
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  10 | valid loss  6.02  5.78 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.3178768157959
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.013022828102111816
s_total_loss1.item()/UPDATE_INTERVAL :  0.013101869821548462
w_total_loss0.item()/UPDATE_INTERVAL :  0.012413835525512696
w_total_loss1.item()/UPDATE_INTERVAL :  0.012829406261444092
| epoch  11 |     0/  184 batches | ms/batch  6.77 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.5940239429474
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  11 | valid loss  5.89  5.71 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.58888721466064
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.014651522636413575
s_total_loss1.item()/UPDATE_INTERVAL :  0.014683270454406738
w_total_loss0.item()/UPDATE_INTERVAL :  0.014408788681030273
w_total_loss1.item()/UPDATE_INTERVAL :  0.014673652648925782
| epoch  12 |     0/  184 batches | ms/batch  6.71 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.0257751941681
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  12 | valid loss  5.87  5.68 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.05476546287537
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.013359426259994507
s_total_loss1.item()/UPDATE_INTERVAL :  0.013674383163452148
w_total_loss0.item()/UPDATE_INTERVAL :  0.013194859027862549
w_total_loss1.item()/UPDATE_INTERVAL :  0.013172444105148316
| epoch  13 |     0/  184 batches | ms/batch  6.74 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.16789865493774
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  13 | valid loss  5.88  5.63 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.17013478279114
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01218847393989563
s_total_loss1.item()/UPDATE_INTERVAL :  0.012197810411453246
w_total_loss0.item()/UPDATE_INTERVAL :  0.01247855305671692
w_total_loss1.item()/UPDATE_INTERVAL :  0.012738162279129028
| epoch  14 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.3981478214264
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  14 | valid loss  5.96  5.65 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.31143283843994
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.013064461946487426
s_total_loss1.item()/UPDATE_INTERVAL :  0.013125489950180053
w_total_loss0.item()/UPDATE_INTERVAL :  0.01219162106513977
w_total_loss1.item()/UPDATE_INTERVAL :  0.012390062808990479
| epoch  15 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.68722248077393
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  15 | valid loss  5.88  5.58 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.50551986694336
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.014333406686782837
s_total_loss1.item()/UPDATE_INTERVAL :  0.014361895322799682
w_total_loss0.item()/UPDATE_INTERVAL :  0.013339438438415528
w_total_loss1.item()/UPDATE_INTERVAL :  0.013533225059509277
| epoch  16 |     0/  184 batches | ms/batch  6.81 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  241.66819667816162
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  391.23157358169556
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  16 | valid loss  5.85  5.45 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  426.41681838035583
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.014542813301086427
s_total_loss1.item()/UPDATE_INTERVAL :  0.014788225889205933
w_total_loss0.item()/UPDATE_INTERVAL :  0.014647091627120972
w_total_loss1.item()/UPDATE_INTERVAL :  0.014535603523254394
| epoch  17 |     0/  184 batches | ms/batch  6.87 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.2424077987671
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  17 | valid loss  5.80  5.48 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.7868275642395
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01252000331878662
s_total_loss1.item()/UPDATE_INTERVAL :  0.012694541215896606
w_total_loss0.item()/UPDATE_INTERVAL :  0.012103451490402222
w_total_loss1.item()/UPDATE_INTERVAL :  0.011913398504257202
| epoch  18 |     0/  184 batches | ms/batch  6.90 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.44173955917358
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  18 | valid loss  5.80  5.50 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.49963974952698
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.012495514154434204
s_total_loss1.item()/UPDATE_INTERVAL :  0.012604715824127198
w_total_loss0.item()/UPDATE_INTERVAL :  0.012810419797897338
w_total_loss1.item()/UPDATE_INTERVAL :  0.012927989959716796
| epoch  19 |     0/  184 batches | ms/batch  6.69 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.47993659973145
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  19 | valid loss  5.77  5.42 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.4969663619995
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011839848756790162
s_total_loss1.item()/UPDATE_INTERVAL :  0.011929575204849243
w_total_loss0.item()/UPDATE_INTERVAL :  0.010818198919296265
w_total_loss1.item()/UPDATE_INTERVAL :  0.011352165937423705
| epoch  20 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.51703238487244
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  20 | valid loss  5.72  5.39 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.41391515731812
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011264804601669311
s_total_loss1.item()/UPDATE_INTERVAL :  0.011280685663223267
w_total_loss0.item()/UPDATE_INTERVAL :  0.01077310085296631
w_total_loss1.item()/UPDATE_INTERVAL :  0.011010855436325073
| epoch  21 |     0/  184 batches | ms/batch  6.81 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.65447640419006
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  21 | valid loss  5.73  5.34 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.60009145736694
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.012856451272964477
s_total_loss1.item()/UPDATE_INTERVAL :  0.012912498712539673
w_total_loss0.item()/UPDATE_INTERVAL :  0.011648597717285157
w_total_loss1.item()/UPDATE_INTERVAL :  0.011605676412582398
| epoch  22 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.48106217384338
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  22 | valid loss  5.64  5.26 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.21034812927246
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011271268129348755
s_total_loss1.item()/UPDATE_INTERVAL :  0.011466583013534546
w_total_loss0.item()/UPDATE_INTERVAL :  0.010196795463562012
w_total_loss1.item()/UPDATE_INTERVAL :  0.010455857515335083
| epoch  23 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.7966010570526
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  23 | valid loss  5.72  5.28 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.76798391342163
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.014388927221298219
s_total_loss1.item()/UPDATE_INTERVAL :  0.014562338590621948
w_total_loss0.item()/UPDATE_INTERVAL :  0.012817392349243164
w_total_loss1.item()/UPDATE_INTERVAL :  0.013016430139541625
| epoch  24 |     0/  184 batches | ms/batch  7.06 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  240.81076097488403
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  388.9264042377472
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  24 | valid loss  5.73  5.32 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  423.85378313064575
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.01301784873008728
s_total_loss1.item()/UPDATE_INTERVAL :  0.013080419301986694
w_total_loss0.item()/UPDATE_INTERVAL :  0.012241020202636718
w_total_loss1.item()/UPDATE_INTERVAL :  0.012108675241470336
| epoch  25 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.4009473323822
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  25 | valid loss  5.66  5.23 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.400217294693
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.014287856817245483
s_total_loss1.item()/UPDATE_INTERVAL :  0.014252766370773315
w_total_loss0.item()/UPDATE_INTERVAL :  0.013587042093276977
w_total_loss1.item()/UPDATE_INTERVAL :  0.013331096172332763
| epoch  26 |     0/  184 batches | ms/batch  6.82 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.47341513633728
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  26 | valid loss  5.64  5.23 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.34947872161865
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.013040741682052612
s_total_loss1.item()/UPDATE_INTERVAL :  0.013185149431228638
w_total_loss0.item()/UPDATE_INTERVAL :  0.012332886457443237
w_total_loss1.item()/UPDATE_INTERVAL :  0.012335740327835083
| epoch  27 |     0/  184 batches | ms/batch  6.77 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.49305319786072
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  27 | valid loss  5.65  5.25 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.18805074691772
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01254555344581604
s_total_loss1.item()/UPDATE_INTERVAL :  0.012659405469894408
w_total_loss0.item()/UPDATE_INTERVAL :  0.011703587770462036
w_total_loss1.item()/UPDATE_INTERVAL :  0.012179042100906373
| epoch  28 |     0/  184 batches | ms/batch  6.92 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.28086280822754
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  28 | valid loss  5.55  5.10 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.10937356948853
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011675882339477538
s_total_loss1.item()/UPDATE_INTERVAL :  0.011619745492935181
w_total_loss0.item()/UPDATE_INTERVAL :  0.010761466026306152
w_total_loss1.item()/UPDATE_INTERVAL :  0.010720252990722656
| epoch  29 |     0/  184 batches | ms/batch  6.56 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.19028186798096
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  29 | valid loss  5.61  5.15 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.06646943092346
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.012714086771011353
s_total_loss1.item()/UPDATE_INTERVAL :  0.012868236303329467
w_total_loss0.item()/UPDATE_INTERVAL :  0.011324542760848998
w_total_loss1.item()/UPDATE_INTERVAL :  0.01141257882118225
| epoch  30 |     0/  184 batches | ms/batch  6.72 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.68924069404602
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  30 | valid loss  5.57  5.04 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.61536812782288
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011162372827529908
s_total_loss1.item()/UPDATE_INTERVAL :  0.011195740699768066
w_total_loss0.item()/UPDATE_INTERVAL :  0.0105890691280365
w_total_loss1.item()/UPDATE_INTERVAL :  0.010882354974746704
| epoch  31 |     0/  184 batches | ms/batch  6.82 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.51661467552185
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  31 | valid loss  5.62  5.14 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.1306836605072
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.012907181978225707
s_total_loss1.item()/UPDATE_INTERVAL :  0.013044389486312867
w_total_loss0.item()/UPDATE_INTERVAL :  0.011908563375473023
w_total_loss1.item()/UPDATE_INTERVAL :  0.012458714246749878
| epoch  32 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  238.9535517692566
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  386.9684064388275
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  32 | valid loss  5.54  5.09 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  421.88796043395996
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.010741735696792603
s_total_loss1.item()/UPDATE_INTERVAL :  0.010972203016281127
w_total_loss0.item()/UPDATE_INTERVAL :  0.009692409634590149
w_total_loss1.item()/UPDATE_INTERVAL :  0.009774401783943176
| epoch  33 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.44462037086487
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  33 | valid loss  5.53  5.10 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.18686413764954
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01239465594291687
s_total_loss1.item()/UPDATE_INTERVAL :  0.01234821081161499
w_total_loss0.item()/UPDATE_INTERVAL :  0.011276857852935791
w_total_loss1.item()/UPDATE_INTERVAL :  0.011363457441329956
| epoch  34 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.45627522468567
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  34 | valid loss  5.51  5.03 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.28150272369385
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011291626691818237
s_total_loss1.item()/UPDATE_INTERVAL :  0.011217310428619384
w_total_loss0.item()/UPDATE_INTERVAL :  0.010623103380203247
w_total_loss1.item()/UPDATE_INTERVAL :  0.011202441453933716
| epoch  35 |     0/  184 batches | ms/batch  6.77 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.02442622184753
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  35 | valid loss  5.58  5.13 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.89666390419006
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.013404747247695923
s_total_loss1.item()/UPDATE_INTERVAL :  0.013853363990783692
w_total_loss0.item()/UPDATE_INTERVAL :  0.012349394559860229
w_total_loss1.item()/UPDATE_INTERVAL :  0.012493743896484374
| epoch  36 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.367431640625
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  36 | valid loss  5.48  5.01 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.40229034423828
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010687626600265503
s_total_loss1.item()/UPDATE_INTERVAL :  0.01077283501625061
w_total_loss0.item()/UPDATE_INTERVAL :  0.009906041026115418
w_total_loss1.item()/UPDATE_INTERVAL :  0.010361944437026977
| epoch  37 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.47243189811707
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  37 | valid loss  5.52  5.01 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.397705078125
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011847653388977052
s_total_loss1.item()/UPDATE_INTERVAL :  0.011870558261871339
w_total_loss0.item()/UPDATE_INTERVAL :  0.010563899278640747
w_total_loss1.item()/UPDATE_INTERVAL :  0.010346254110336304
| epoch  38 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.70250940322876
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  38 | valid loss  5.52  5.05 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.77882766723633
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011696435213088989
s_total_loss1.item()/UPDATE_INTERVAL :  0.012058106660842895
w_total_loss0.item()/UPDATE_INTERVAL :  0.010742415189743042
w_total_loss1.item()/UPDATE_INTERVAL :  0.011091752052307129
| epoch  39 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.74507451057434
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  39 | valid loss  5.51  5.07 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.4595823287964
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.012414096593856812
s_total_loss1.item()/UPDATE_INTERVAL :  0.012407057285308838
w_total_loss0.item()/UPDATE_INTERVAL :  0.01169756531715393
w_total_loss1.item()/UPDATE_INTERVAL :  0.011911956071853637
| epoch  40 |     0/  184 batches | ms/batch  6.64 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  240.27522897720337
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  388.27732491493225
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  40 | valid loss  5.50  5.05 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  423.28297543525696
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.011193612813949585
s_total_loss1.item()/UPDATE_INTERVAL :  0.011048320531845093
w_total_loss0.item()/UPDATE_INTERVAL :  0.008956897258758544
w_total_loss1.item()/UPDATE_INTERVAL :  0.00908747136592865
| epoch  41 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.75840497016907
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  41 | valid loss  5.56  5.01 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.6798915863037
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011705600023269654
s_total_loss1.item()/UPDATE_INTERVAL :  0.011808544397354126
w_total_loss0.item()/UPDATE_INTERVAL :  0.01113404393196106
w_total_loss1.item()/UPDATE_INTERVAL :  0.011494715213775635
| epoch  42 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.76841497421265
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  42 | valid loss  5.41  4.87 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.69511723518372
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011069912910461426
s_total_loss1.item()/UPDATE_INTERVAL :  0.011131222248077393
w_total_loss0.item()/UPDATE_INTERVAL :  0.009879491925239563
w_total_loss1.item()/UPDATE_INTERVAL :  0.010151902437210083
| epoch  43 |     0/  184 batches | ms/batch  6.82 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.12116312980652
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  43 | valid loss  5.50  4.97 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.01196885108948
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010923150777816772
s_total_loss1.item()/UPDATE_INTERVAL :  0.01104735016822815
w_total_loss0.item()/UPDATE_INTERVAL :  0.009836339950561523
w_total_loss1.item()/UPDATE_INTERVAL :  0.00995851993560791
| epoch  44 |     0/  184 batches | ms/batch  6.96 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.00231885910034
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  44 | valid loss  5.40  4.91 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.86970472335815
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009885274767875672
s_total_loss1.item()/UPDATE_INTERVAL :  0.009969577789306641
w_total_loss0.item()/UPDATE_INTERVAL :  0.009420703053474427
w_total_loss1.item()/UPDATE_INTERVAL :  0.009410405158996582
| epoch  45 |     0/  184 batches | ms/batch  6.66 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.51157093048096
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  45 | valid loss  5.46  4.95 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.53055548667908
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011194522380828858
s_total_loss1.item()/UPDATE_INTERVAL :  0.011135599613189696
w_total_loss0.item()/UPDATE_INTERVAL :  0.010822771787643433
w_total_loss1.item()/UPDATE_INTERVAL :  0.01075212836265564
| epoch  46 |     0/  184 batches | ms/batch  6.91 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.82878708839417
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  46 | valid loss  5.37  4.84 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.80619931221008
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011682124137878417
s_total_loss1.item()/UPDATE_INTERVAL :  0.011887480020523072
w_total_loss0.item()/UPDATE_INTERVAL :  0.011558150053024291
w_total_loss1.item()/UPDATE_INTERVAL :  0.01163615584373474
| epoch  47 |     0/  184 batches | ms/batch  6.91 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.91614079475403
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  47 | valid loss  5.44  5.01 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.07101202011108
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009429075717926026
s_total_loss1.item()/UPDATE_INTERVAL :  0.009487571716308594
w_total_loss0.item()/UPDATE_INTERVAL :  0.009371218681335449
w_total_loss1.item()/UPDATE_INTERVAL :  0.009348219037055969
| epoch  48 |     0/  184 batches | ms/batch  6.70 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  240.1978120803833
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  388.9277865886688
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  48 | valid loss  5.45  4.85 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  423.9780945777893
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.01065786600112915
s_total_loss1.item()/UPDATE_INTERVAL :  0.010946193933486939
w_total_loss0.item()/UPDATE_INTERVAL :  0.009873333573341369
w_total_loss1.item()/UPDATE_INTERVAL :  0.010203194618225098
| epoch  49 |     0/  184 batches | ms/batch  6.70 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.50746989250183
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  49 | valid loss  5.42  4.95 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.5273997783661
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011713504791259766
s_total_loss1.item()/UPDATE_INTERVAL :  0.012113783359527588
w_total_loss0.item()/UPDATE_INTERVAL :  0.01165941596031189
w_total_loss1.item()/UPDATE_INTERVAL :  0.011927618980407714
| epoch  50 |     0/  184 batches | ms/batch  6.71 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.87392163276672
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  50 | valid loss  5.39  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.03980231285095
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010188194513320923
s_total_loss1.item()/UPDATE_INTERVAL :  0.010369510650634765
w_total_loss0.item()/UPDATE_INTERVAL :  0.009798089861869813
w_total_loss1.item()/UPDATE_INTERVAL :  0.010017889738082885
| epoch  51 |     0/  184 batches | ms/batch  6.78 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.8448040485382
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  51 | valid loss  5.30  4.79 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.8537893295288
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011596440076828004
s_total_loss1.item()/UPDATE_INTERVAL :  0.011553380489349365
w_total_loss0.item()/UPDATE_INTERVAL :  0.0118646502494812
w_total_loss1.item()/UPDATE_INTERVAL :  0.0117742919921875
| epoch  52 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.7802438735962
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  52 | valid loss  5.47  4.94 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.6972393989563
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010629639625549317
s_total_loss1.item()/UPDATE_INTERVAL :  0.01095103621482849
w_total_loss0.item()/UPDATE_INTERVAL :  0.010489282608032226
w_total_loss1.item()/UPDATE_INTERVAL :  0.010571378469467162
| epoch  53 |     0/  184 batches | ms/batch  6.75 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.29290390014648
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  53 | valid loss  5.34  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.19656348228455
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011464604139328004
s_total_loss1.item()/UPDATE_INTERVAL :  0.011681338548660278
w_total_loss0.item()/UPDATE_INTERVAL :  0.010403329133987426
w_total_loss1.item()/UPDATE_INTERVAL :  0.010381385087966918
| epoch  54 |     0/  184 batches | ms/batch  6.78 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  138.77867341041565
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  54 | valid loss  5.37  4.85 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.36717200279236
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009446799159049987
s_total_loss1.item()/UPDATE_INTERVAL :  0.009704822897911072
w_total_loss0.item()/UPDATE_INTERVAL :  0.009444093704223633
w_total_loss1.item()/UPDATE_INTERVAL :  0.009190528392791749
| epoch  55 |     0/  184 batches | ms/batch  6.76 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  138.94644260406494
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  55 | valid loss  5.45  4.87 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.67850828170776
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011624935865402222
s_total_loss1.item()/UPDATE_INTERVAL :  0.011802268028259278
w_total_loss0.item()/UPDATE_INTERVAL :  0.010332584381103516
w_total_loss1.item()/UPDATE_INTERVAL :  0.010566021203994752
| epoch  56 |     0/  184 batches | ms/batch  6.48 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  233.74878668785095
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  381.20113921165466
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  56 | valid loss  5.46  4.85 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  416.2606792449951
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.01187807321548462
s_total_loss1.item()/UPDATE_INTERVAL :  0.011961225271224975
w_total_loss0.item()/UPDATE_INTERVAL :  0.009948102831840515
w_total_loss1.item()/UPDATE_INTERVAL :  0.010205559730529785
| epoch  57 |     0/  184 batches | ms/batch  6.97 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  138.97395038604736
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  57 | valid loss  5.40  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.3043897151947
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009768011569976807
s_total_loss1.item()/UPDATE_INTERVAL :  0.009824226498603822
w_total_loss0.item()/UPDATE_INTERVAL :  0.008895084261894226
w_total_loss1.item()/UPDATE_INTERVAL :  0.008728404045104981
| epoch  58 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  138.90977478027344
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  58 | valid loss  5.39  4.90 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.47890067100525
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010210268497467041
s_total_loss1.item()/UPDATE_INTERVAL :  0.010126138925552369
w_total_loss0.item()/UPDATE_INTERVAL :  0.00877156674861908
w_total_loss1.item()/UPDATE_INTERVAL :  0.008637552261352538
| epoch  59 |     0/  184 batches | ms/batch  6.65 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.34882712364197
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  59 | valid loss  5.35  4.81 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.9778597354889
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010090733766555787
s_total_loss1.item()/UPDATE_INTERVAL :  0.010299078226089477
w_total_loss0.item()/UPDATE_INTERVAL :  0.008599562644958496
w_total_loss1.item()/UPDATE_INTERVAL :  0.008905115127563477
| epoch  60 |     0/  184 batches | ms/batch  6.99 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.47895574569702
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  60 | valid loss  5.45  4.89 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.1756808757782
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010219955444335937
s_total_loss1.item()/UPDATE_INTERVAL :  0.010281620025634765
w_total_loss0.item()/UPDATE_INTERVAL :  0.00939289629459381
w_total_loss1.item()/UPDATE_INTERVAL :  0.009531695246696472
| epoch  61 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.07357549667358
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  61 | valid loss  5.33  4.74 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.75612139701843
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011546428203582764
s_total_loss1.item()/UPDATE_INTERVAL :  0.011498465538024902
w_total_loss0.item()/UPDATE_INTERVAL :  0.01074006199836731
w_total_loss1.item()/UPDATE_INTERVAL :  0.011162270307540894
| epoch  62 |     0/  184 batches | ms/batch  6.81 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.35984802246094
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  62 | valid loss  5.35  4.77 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.26942682266235
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010614353418350219
s_total_loss1.item()/UPDATE_INTERVAL :  0.010692639350891113
w_total_loss0.item()/UPDATE_INTERVAL :  0.009638447761535645
w_total_loss1.item()/UPDATE_INTERVAL :  0.009742498397827148
| epoch  63 |     0/  184 batches | ms/batch  6.98 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.19879961013794
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  63 | valid loss  5.34  4.77 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.91691517829895
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008872966766357421
s_total_loss1.item()/UPDATE_INTERVAL :  0.00898967206478119
w_total_loss0.item()/UPDATE_INTERVAL :  0.007848945260047913
w_total_loss1.item()/UPDATE_INTERVAL :  0.008020270466804504
| epoch  64 |     0/  184 batches | ms/batch  6.75 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  242.4933488368988
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  390.36488938331604
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  64 | valid loss  5.27  4.73 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  425.51312017440796
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.010345336198806763
s_total_loss1.item()/UPDATE_INTERVAL :  0.010637151002883911
w_total_loss0.item()/UPDATE_INTERVAL :  0.009603929519653321
w_total_loss1.item()/UPDATE_INTERVAL :  0.009749467968940734
| epoch  65 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.3074176311493
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  65 | valid loss  5.38  4.84 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.18272519111633
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011024941205978394
s_total_loss1.item()/UPDATE_INTERVAL :  0.011189274787902832
w_total_loss0.item()/UPDATE_INTERVAL :  0.009794858098030091
w_total_loss1.item()/UPDATE_INTERVAL :  0.009562103152275086
| epoch  66 |     0/  184 batches | ms/batch  6.81 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.26461172103882
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  66 | valid loss  5.42  4.84 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.197772026062
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010781408548355102
s_total_loss1.item()/UPDATE_INTERVAL :  0.010799692869186401
w_total_loss0.item()/UPDATE_INTERVAL :  0.00976259469985962
w_total_loss1.item()/UPDATE_INTERVAL :  0.009642731547355652
| epoch  67 |     0/  184 batches | ms/batch  6.74 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.6067202091217
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  67 | valid loss  5.34  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.48896741867065
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.00937301218509674
s_total_loss1.item()/UPDATE_INTERVAL :  0.009782915711402893
w_total_loss0.item()/UPDATE_INTERVAL :  0.00782891273498535
w_total_loss1.item()/UPDATE_INTERVAL :  0.008032517433166504
| epoch  68 |     0/  184 batches | ms/batch  6.82 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.77859449386597
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  68 | valid loss  5.36  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.4515244960785
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01086719036102295
s_total_loss1.item()/UPDATE_INTERVAL :  0.010834482908248901
w_total_loss0.item()/UPDATE_INTERVAL :  0.009407508969306946
w_total_loss1.item()/UPDATE_INTERVAL :  0.009517464637756348
| epoch  69 |     0/  184 batches | ms/batch  6.75 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.5080270767212
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  69 | valid loss  5.35  4.66 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.4279453754425
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01057996392250061
s_total_loss1.item()/UPDATE_INTERVAL :  0.010387033224105835
w_total_loss0.item()/UPDATE_INTERVAL :  0.009676020741462708
w_total_loss1.item()/UPDATE_INTERVAL :  0.009535629153251648
| epoch  70 |     0/  184 batches | ms/batch  6.82 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.3102252483368
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  70 | valid loss  5.29  4.73 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.96921610832214
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010590871572494507
s_total_loss1.item()/UPDATE_INTERVAL :  0.010849710702896118
w_total_loss0.item()/UPDATE_INTERVAL :  0.010090874433517456
w_total_loss1.item()/UPDATE_INTERVAL :  0.01015432357788086
| epoch  71 |     0/  184 batches | ms/batch  6.76 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  138.92129254341125
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  71 | valid loss  5.46  4.87 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  173.9850947856903
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011800622940063477
s_total_loss1.item()/UPDATE_INTERVAL :  0.011813586950302124
w_total_loss0.item()/UPDATE_INTERVAL :  0.010828944444656373
w_total_loss1.item()/UPDATE_INTERVAL :  0.011158446073532105
| epoch  72 |     0/  184 batches | ms/batch  6.86 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  237.4862983226776
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  385.5274167060852
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  72 | valid loss  5.38  4.72 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  419.9708580970764
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.010471869707107544
s_total_loss1.item()/UPDATE_INTERVAL :  0.01058668851852417
w_total_loss0.item()/UPDATE_INTERVAL :  0.009693369269371033
w_total_loss1.item()/UPDATE_INTERVAL :  0.009690134525299073
| epoch  73 |     0/  184 batches | ms/batch  6.73 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.46144104003906
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  73 | valid loss  5.40  4.79 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  176.1797308921814
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010831919908523559
s_total_loss1.item()/UPDATE_INTERVAL :  0.011001880168914796
w_total_loss0.item()/UPDATE_INTERVAL :  0.009692488312721253
w_total_loss1.item()/UPDATE_INTERVAL :  0.009879440665245057
| epoch  74 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.95218086242676
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  74 | valid loss  5.33  4.72 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.77553272247314
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010451534986495972
s_total_loss1.item()/UPDATE_INTERVAL :  0.010464450120925903
w_total_loss0.item()/UPDATE_INTERVAL :  0.011171225309371948
w_total_loss1.item()/UPDATE_INTERVAL :  0.01099167823791504
| epoch  75 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.12613892555237
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  75 | valid loss  5.37  4.78 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.4483141899109
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009231469035148621
s_total_loss1.item()/UPDATE_INTERVAL :  0.009377570152282714
w_total_loss0.item()/UPDATE_INTERVAL :  0.007839102745056153
w_total_loss1.item()/UPDATE_INTERVAL :  0.008149463534355163
| epoch  76 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.44582629203796
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  76 | valid loss  5.37  4.71 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.85103821754456
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010889989137649537
s_total_loss1.item()/UPDATE_INTERVAL :  0.011009432077407837
w_total_loss0.item()/UPDATE_INTERVAL :  0.010586360692977905
w_total_loss1.item()/UPDATE_INTERVAL :  0.01109993577003479
| epoch  77 |     0/  184 batches | ms/batch  6.76 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.13511729240417
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  77 | valid loss  5.29  4.74 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.25565552711487
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010589077472686767
s_total_loss1.item()/UPDATE_INTERVAL :  0.010768567323684692
w_total_loss0.item()/UPDATE_INTERVAL :  0.010030257701873779
w_total_loss1.item()/UPDATE_INTERVAL :  0.010017372369766235
| epoch  78 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.32604503631592
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  78 | valid loss  5.39  4.79 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.68679857254028
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010843762159347535
s_total_loss1.item()/UPDATE_INTERVAL :  0.010851410627365112
w_total_loss0.item()/UPDATE_INTERVAL :  0.009681704640388488
w_total_loss1.item()/UPDATE_INTERVAL :  0.009684341549873353
| epoch  79 |     0/  184 batches | ms/batch  6.75 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.59873461723328
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  79 | valid loss  5.37  4.78 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.91638135910034
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010116928815841674
s_total_loss1.item()/UPDATE_INTERVAL :  0.010226765871047974
w_total_loss0.item()/UPDATE_INTERVAL :  0.009367823004722595
w_total_loss1.item()/UPDATE_INTERVAL :  0.009342090487480163
| epoch  80 |     0/  184 batches | ms/batch  6.96 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  238.99593949317932
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  387.61053681373596
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  80 | valid loss  5.30  4.72 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  422.9483094215393
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.013490720987319946
s_total_loss1.item()/UPDATE_INTERVAL :  0.013668031692504882
w_total_loss0.item()/UPDATE_INTERVAL :  0.01386939525604248
w_total_loss1.item()/UPDATE_INTERVAL :  0.013565500974655151
| epoch  81 |     0/  184 batches | ms/batch  7.02 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.49108052253723
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  81 | valid loss  5.22  4.65 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.75287580490112
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010028139352798462
s_total_loss1.item()/UPDATE_INTERVAL :  0.010087565183639527
w_total_loss0.item()/UPDATE_INTERVAL :  0.008923787474632263
w_total_loss1.item()/UPDATE_INTERVAL :  0.008805953860282899
| epoch  82 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.18988180160522
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  82 | valid loss  5.20  4.64 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.33759689331055
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011258270740509033
s_total_loss1.item()/UPDATE_INTERVAL :  0.011389895677566528
w_total_loss0.item()/UPDATE_INTERVAL :  0.009398005008697509
w_total_loss1.item()/UPDATE_INTERVAL :  0.009363853931427002
| epoch  83 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.39711046218872
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  83 | valid loss  5.35  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.59060645103455
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01029161810874939
s_total_loss1.item()/UPDATE_INTERVAL :  0.010414333343505859
w_total_loss0.item()/UPDATE_INTERVAL :  0.00967641055583954
w_total_loss1.item()/UPDATE_INTERVAL :  0.010007340908050538
| epoch  84 |     0/  184 batches | ms/batch  6.95 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.38532423973083
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  84 | valid loss  5.32  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.24432706832886
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.012550898790359498
s_total_loss1.item()/UPDATE_INTERVAL :  0.01253563642501831
w_total_loss0.item()/UPDATE_INTERVAL :  0.011327494382858277
w_total_loss1.item()/UPDATE_INTERVAL :  0.01112197995185852
| epoch  85 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.36295652389526
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  85 | valid loss  5.30  4.73 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.89386677742004
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.00984227418899536
s_total_loss1.item()/UPDATE_INTERVAL :  0.009786047339439392
w_total_loss0.item()/UPDATE_INTERVAL :  0.00875173270702362
w_total_loss1.item()/UPDATE_INTERVAL :  0.008522672057151794
| epoch  86 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.87826657295227
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  86 | valid loss  5.25  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.91583967208862
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011098047494888305
s_total_loss1.item()/UPDATE_INTERVAL :  0.011114526987075806
w_total_loss0.item()/UPDATE_INTERVAL :  0.009421731829643249
w_total_loss1.item()/UPDATE_INTERVAL :  0.009583624005317688
| epoch  87 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.59096598625183
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  87 | valid loss  5.40  4.83 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.7139835357666
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010014959573745728
s_total_loss1.item()/UPDATE_INTERVAL :  0.01050212860107422
w_total_loss0.item()/UPDATE_INTERVAL :  0.009106144309043884
w_total_loss1.item()/UPDATE_INTERVAL :  0.009249162077903748
| epoch  88 |     0/  184 batches | ms/batch  6.84 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  241.58053827285767
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  391.6136062145233
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  88 | valid loss  5.23  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  426.5545611381531
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.010063295364379882
s_total_loss1.item()/UPDATE_INTERVAL :  0.010024410486221314
w_total_loss0.item()/UPDATE_INTERVAL :  0.008568065166473389
w_total_loss1.item()/UPDATE_INTERVAL :  0.008747368454933166
| epoch  89 |     0/  184 batches | ms/batch  6.74 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.32255220413208
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  89 | valid loss  5.32  4.70 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.65307474136353
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009552968144416809
s_total_loss1.item()/UPDATE_INTERVAL :  0.009786992073059083
w_total_loss0.item()/UPDATE_INTERVAL :  0.009664375185966492
w_total_loss1.item()/UPDATE_INTERVAL :  0.01004712700843811
| epoch  90 |     0/  184 batches | ms/batch  6.77 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.5743272304535
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  90 | valid loss  5.19  4.59 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.81872749328613
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010148439407348633
s_total_loss1.item()/UPDATE_INTERVAL :  0.010181611776351929
w_total_loss0.item()/UPDATE_INTERVAL :  0.008686890602111816
w_total_loss1.item()/UPDATE_INTERVAL :  0.008399686813354491
| epoch  91 |     0/  184 batches | ms/batch  6.75 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.3858346939087
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  91 | valid loss  5.26  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.57532954216003
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010110279321670532
s_total_loss1.item()/UPDATE_INTERVAL :  0.010224305391311646
w_total_loss0.item()/UPDATE_INTERVAL :  0.008577952980995179
w_total_loss1.item()/UPDATE_INTERVAL :  0.008662293553352357
| epoch  92 |     0/  184 batches | ms/batch  6.75 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.6476447582245
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  92 | valid loss  5.28  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.12103390693665
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.00988728940486908
s_total_loss1.item()/UPDATE_INTERVAL :  0.009877576231956483
w_total_loss0.item()/UPDATE_INTERVAL :  0.009528567194938659
w_total_loss1.item()/UPDATE_INTERVAL :  0.009390938282012939
| epoch  93 |     0/  184 batches | ms/batch  6.82 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.2789921760559
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  93 | valid loss  5.23  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.7516746520996
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011577523946762085
s_total_loss1.item()/UPDATE_INTERVAL :  0.011722034215927124
w_total_loss0.item()/UPDATE_INTERVAL :  0.009418871998786927
w_total_loss1.item()/UPDATE_INTERVAL :  0.009456499218940735
| epoch  94 |     0/  184 batches | ms/batch  6.99 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.46383047103882
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  94 | valid loss  5.33  4.75 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.23261213302612
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.00988797664642334
s_total_loss1.item()/UPDATE_INTERVAL :  0.009940476417541503
w_total_loss0.item()/UPDATE_INTERVAL :  0.008926722407341003
w_total_loss1.item()/UPDATE_INTERVAL :  0.009001063704490662
| epoch  95 |     0/  184 batches | ms/batch  6.90 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.39803886413574
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  95 | valid loss  5.27  4.65 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  176.1257345676422
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010038001537322998
s_total_loss1.item()/UPDATE_INTERVAL :  0.010265332460403443
w_total_loss0.item()/UPDATE_INTERVAL :  0.009521331787109375
w_total_loss1.item()/UPDATE_INTERVAL :  0.009732258915901184
| epoch  96 |     0/  184 batches | ms/batch  7.07 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  239.09668445587158
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  389.637056350708
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  96 | valid loss  5.28  4.68 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  424.9656717777252
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.012407772541046143
s_total_loss1.item()/UPDATE_INTERVAL :  0.012634345293045045
w_total_loss0.item()/UPDATE_INTERVAL :  0.010508102178573609
w_total_loss1.item()/UPDATE_INTERVAL :  0.01057306408882141
| epoch  97 |     0/  184 batches | ms/batch  6.89 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.64637804031372
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  97 | valid loss  5.39  4.82 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.85544180870056
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010483771562576294
s_total_loss1.item()/UPDATE_INTERVAL :  0.010941665172576904
w_total_loss0.item()/UPDATE_INTERVAL :  0.00852375030517578
w_total_loss1.item()/UPDATE_INTERVAL :  0.009034517407417297
| epoch  98 |     0/  184 batches | ms/batch  7.03 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.62679052352905
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  98 | valid loss  5.34  4.71 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.7701907157898
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009236752986907959
s_total_loss1.item()/UPDATE_INTERVAL :  0.009087173342704773
w_total_loss0.item()/UPDATE_INTERVAL :  0.009518966674804688
w_total_loss1.item()/UPDATE_INTERVAL :  0.009401345252990722
| epoch  99 |     0/  184 batches | ms/batch  6.90 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.21311688423157
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch  99 | valid loss  5.22  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.92023825645447
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010327781438827515
s_total_loss1.item()/UPDATE_INTERVAL :  0.01049792766571045
w_total_loss0.item()/UPDATE_INTERVAL :  0.008846685886383057
w_total_loss1.item()/UPDATE_INTERVAL :  0.008869494795799255
| epoch 100 |     0/  184 batches | ms/batch  6.93 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.8737506866455
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 100 | valid loss  5.28  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.8384222984314
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009988022446632385
s_total_loss1.item()/UPDATE_INTERVAL :  0.009972308278083802
w_total_loss0.item()/UPDATE_INTERVAL :  0.009376983642578125
w_total_loss1.item()/UPDATE_INTERVAL :  0.00953080177307129
| epoch 101 |     0/  184 batches | ms/batch  6.76 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.91163277626038
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 101 | valid loss  5.30  4.72 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.92164421081543
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009469004273414612
s_total_loss1.item()/UPDATE_INTERVAL :  0.009569801688194275
w_total_loss0.item()/UPDATE_INTERVAL :  0.009206508994102478
w_total_loss1.item()/UPDATE_INTERVAL :  0.00908510982990265
| epoch 102 |     0/  184 batches | ms/batch  6.98 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.4430570602417
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 102 | valid loss  5.21  4.61 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.6322922706604
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010893986225128174
s_total_loss1.item()/UPDATE_INTERVAL :  0.010892530679702759
w_total_loss0.item()/UPDATE_INTERVAL :  0.009481465220451355
w_total_loss1.item()/UPDATE_INTERVAL :  0.009782746434211731
| epoch 103 |     0/  184 batches | ms/batch  6.97 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.27868247032166
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 103 | valid loss  5.19  4.60 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.00695061683655
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010271179676055908
s_total_loss1.item()/UPDATE_INTERVAL :  0.01035951018333435
w_total_loss0.item()/UPDATE_INTERVAL :  0.009826116561889649
w_total_loss1.item()/UPDATE_INTERVAL :  0.009565147757530212
| epoch 104 |     0/  184 batches | ms/batch  6.69 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  237.30290246009827
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  387.81589698791504
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 104 | valid loss  5.27  4.66 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  422.62726354599
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.011036938428878785
s_total_loss1.item()/UPDATE_INTERVAL :  0.011005722284317017
w_total_loss0.item()/UPDATE_INTERVAL :  0.010922715663909913
w_total_loss1.item()/UPDATE_INTERVAL :  0.010460926294326782
| epoch 105 |     0/  184 batches | ms/batch  6.79 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  139.96435117721558
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 105 | valid loss  5.28  4.73 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.24063754081726
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009133472442626953
s_total_loss1.item()/UPDATE_INTERVAL :  0.009314768314361573
w_total_loss0.item()/UPDATE_INTERVAL :  0.008104093670845032
w_total_loss1.item()/UPDATE_INTERVAL :  0.00848355770111084
| epoch 106 |     0/  184 batches | ms/batch  7.00 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.60209155082703
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 106 | valid loss  5.31  4.72 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.1897895336151
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010080121755599976
s_total_loss1.item()/UPDATE_INTERVAL :  0.010159376859664917
w_total_loss0.item()/UPDATE_INTERVAL :  0.009144339561462402
w_total_loss1.item()/UPDATE_INTERVAL :  0.009287860989570618
| epoch 107 |     0/  184 batches | ms/batch  6.90 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.3495306968689
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 107 | valid loss  5.27  4.72 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.567232131958
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008728076815605163
s_total_loss1.item()/UPDATE_INTERVAL :  0.00885032832622528
w_total_loss0.item()/UPDATE_INTERVAL :  0.008440870642662048
w_total_loss1.item()/UPDATE_INTERVAL :  0.008712060451507568
| epoch 108 |     0/  184 batches | ms/batch  6.73 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.66909289360046
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 108 | valid loss  5.22  4.63 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.44688534736633
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.01036946415901184
s_total_loss1.item()/UPDATE_INTERVAL :  0.010737186670303345
w_total_loss0.item()/UPDATE_INTERVAL :  0.00865634262561798
w_total_loss1.item()/UPDATE_INTERVAL :  0.008750268816947937
| epoch 109 |     0/  184 batches | ms/batch  6.92 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.43997073173523
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 109 | valid loss  5.27  4.66 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.40087890625
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009843361973762512
s_total_loss1.item()/UPDATE_INTERVAL :  0.00985293447971344
w_total_loss0.item()/UPDATE_INTERVAL :  0.009323126673698424
w_total_loss1.item()/UPDATE_INTERVAL :  0.009425259232521056
| epoch 110 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.63317346572876
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 110 | valid loss  5.30  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.4602189064026
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009933173060417175
s_total_loss1.item()/UPDATE_INTERVAL :  0.010182749032974243
w_total_loss0.item()/UPDATE_INTERVAL :  0.009624314308166505
w_total_loss1.item()/UPDATE_INTERVAL :  0.009627324938774108
| epoch 111 |     0/  184 batches | ms/batch  6.81 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.53118085861206
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 111 | valid loss  5.18  4.59 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.65920519828796
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009684613347053528
s_total_loss1.item()/UPDATE_INTERVAL :  0.00982103407382965
w_total_loss0.item()/UPDATE_INTERVAL :  0.007739038467407227
w_total_loss1.item()/UPDATE_INTERVAL :  0.008237072825431823
| epoch 112 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  234.53792333602905
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  383.91327476501465
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 112 | valid loss  5.27  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  418.46770787239075
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.00809885084629059
s_total_loss1.item()/UPDATE_INTERVAL :  0.008137593269348145
w_total_loss0.item()/UPDATE_INTERVAL :  0.006596919298171997
w_total_loss1.item()/UPDATE_INTERVAL :  0.00693359375
| epoch 113 |     0/  184 batches | ms/batch  6.93 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.26264262199402
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 113 | valid loss  5.23  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.4640920162201
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.012047587633132935
s_total_loss1.item()/UPDATE_INTERVAL :  0.012703074216842651
w_total_loss0.item()/UPDATE_INTERVAL :  0.010309675931930542
w_total_loss1.item()/UPDATE_INTERVAL :  0.010402216911315917
| epoch 114 |     0/  184 batches | ms/batch  6.85 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.5674397945404
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 114 | valid loss  5.24  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.91969227790833
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011069880723953247
s_total_loss1.item()/UPDATE_INTERVAL :  0.011290217638015748
w_total_loss0.item()/UPDATE_INTERVAL :  0.009953818321228027
w_total_loss1.item()/UPDATE_INTERVAL :  0.010003066062927246
| epoch 115 |     0/  184 batches | ms/batch  6.82 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.25540328025818
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 115 | valid loss  5.17  4.56 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.78835606575012
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009977216124534607
s_total_loss1.item()/UPDATE_INTERVAL :  0.010226339101791382
w_total_loss0.item()/UPDATE_INTERVAL :  0.009247319102287292
w_total_loss1.item()/UPDATE_INTERVAL :  0.009399189949035644
| epoch 116 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.33508610725403
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 116 | valid loss  5.29  4.65 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.41088342666626
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011180825233459472
s_total_loss1.item()/UPDATE_INTERVAL :  0.011229397058486938
w_total_loss0.item()/UPDATE_INTERVAL :  0.010696967840194702
w_total_loss1.item()/UPDATE_INTERVAL :  0.010605174303054809
| epoch 117 |     0/  184 batches | ms/batch  6.86 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.30492329597473
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 117 | valid loss  5.26  4.69 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.6563446521759
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011791542768478394
s_total_loss1.item()/UPDATE_INTERVAL :  0.012249863147735596
w_total_loss0.item()/UPDATE_INTERVAL :  0.010785008668899537
w_total_loss1.item()/UPDATE_INTERVAL :  0.01091707706451416
| epoch 118 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.1670422554016
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 118 | valid loss  5.23  4.66 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.4327187538147
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009413608908653259
s_total_loss1.item()/UPDATE_INTERVAL :  0.009619733691215515
w_total_loss0.item()/UPDATE_INTERVAL :  0.008019046783447266
w_total_loss1.item()/UPDATE_INTERVAL :  0.00808142364025116
| epoch 119 |     0/  184 batches | ms/batch  6.89 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.5435836315155
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 119 | valid loss  5.18  4.65 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.14554286003113
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010518137216567993
s_total_loss1.item()/UPDATE_INTERVAL :  0.010403047800064086
w_total_loss0.item()/UPDATE_INTERVAL :  0.01039915919303894
w_total_loss1.item()/UPDATE_INTERVAL :  0.01023256778717041
| epoch 120 |     0/  184 batches | ms/batch  6.81 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  240.90948271751404
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  390.67173290252686
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 120 | valid loss  5.25  4.61 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  425.7542061805725
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.01095840811729431
s_total_loss1.item()/UPDATE_INTERVAL :  0.011102248430252076
w_total_loss0.item()/UPDATE_INTERVAL :  0.010050996541976928
w_total_loss1.item()/UPDATE_INTERVAL :  0.01032721519470215
| epoch 121 |     0/  184 batches | ms/batch  6.88 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.12783432006836
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 121 | valid loss  5.30  4.65 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.0045280456543
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009664478302001954
s_total_loss1.item()/UPDATE_INTERVAL :  0.009994113445281982
w_total_loss0.item()/UPDATE_INTERVAL :  0.008719889521598816
w_total_loss1.item()/UPDATE_INTERVAL :  0.008872241377830506
| epoch 122 |     0/  184 batches | ms/batch  6.77 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.58549666404724
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 122 | valid loss  5.27  4.63 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.396413564682
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010657001733779908
s_total_loss1.item()/UPDATE_INTERVAL :  0.010692554712295532
w_total_loss0.item()/UPDATE_INTERVAL :  0.009709903597831726
w_total_loss1.item()/UPDATE_INTERVAL :  0.00927466869354248
| epoch 123 |     0/  184 batches | ms/batch  6.76 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.4025387763977
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 123 | valid loss  5.22  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.38533449172974
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008487789034843445
s_total_loss1.item()/UPDATE_INTERVAL :  0.008620161414146423
w_total_loss0.item()/UPDATE_INTERVAL :  0.00784489929676056
w_total_loss1.item()/UPDATE_INTERVAL :  0.00775299072265625
| epoch 124 |     0/  184 batches | ms/batch  6.91 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.95274710655212
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 124 | valid loss  5.25  4.56 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.8778612613678
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009697696566581726
s_total_loss1.item()/UPDATE_INTERVAL :  0.009773553013801575
w_total_loss0.item()/UPDATE_INTERVAL :  0.008963149189949036
w_total_loss1.item()/UPDATE_INTERVAL :  0.009061772227287292
| epoch 125 |     0/  184 batches | ms/batch  6.93 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.26136589050293
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 125 | valid loss  5.29  4.66 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.28269982337952
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010422402620315551
s_total_loss1.item()/UPDATE_INTERVAL :  0.010575608015060425
w_total_loss0.item()/UPDATE_INTERVAL :  0.00912654161453247
w_total_loss1.item()/UPDATE_INTERVAL :  0.009312440752983092
| epoch 126 |     0/  184 batches | ms/batch  6.79 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.66535925865173
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 126 | valid loss  5.17  4.53 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.45886898040771
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008488762378692626
s_total_loss1.item()/UPDATE_INTERVAL :  0.008862969875335693
w_total_loss0.item()/UPDATE_INTERVAL :  0.0076319026947021485
w_total_loss1.item()/UPDATE_INTERVAL :  0.007838203310966492
| epoch 127 |     0/  184 batches | ms/batch  6.72 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.19986081123352
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 127 | valid loss  5.22  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.80279684066772
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009314499497413635
s_total_loss1.item()/UPDATE_INTERVAL :  0.009189061522483825
w_total_loss0.item()/UPDATE_INTERVAL :  0.008919076323509216
w_total_loss1.item()/UPDATE_INTERVAL :  0.008878459930419922
| epoch 128 |     0/  184 batches | ms/batch  6.91 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  236.87982606887817
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  387.3748857975006
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 128 | valid loss  5.31  4.72 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  422.0936133861542
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.008106344342231751
s_total_loss1.item()/UPDATE_INTERVAL :  0.008349177241325379
w_total_loss0.item()/UPDATE_INTERVAL :  0.007934018969535828
w_total_loss1.item()/UPDATE_INTERVAL :  0.007999014854431153
| epoch 129 |     0/  184 batches | ms/batch  6.93 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.46530866622925
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 129 | valid loss  5.29  4.69 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.846661567688
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009208466410636901
s_total_loss1.item()/UPDATE_INTERVAL :  0.009513400197029113
w_total_loss0.item()/UPDATE_INTERVAL :  0.007863872647285462
w_total_loss1.item()/UPDATE_INTERVAL :  0.007592334151268005
| epoch 130 |     0/  184 batches | ms/batch  6.92 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.3739938735962
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 130 | valid loss  5.17  4.55 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.53881573677063
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008731843829154968
s_total_loss1.item()/UPDATE_INTERVAL :  0.008688309788703918
w_total_loss0.item()/UPDATE_INTERVAL :  0.00764448344707489
w_total_loss1.item()/UPDATE_INTERVAL :  0.0072049969434738155
| epoch 131 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.60332798957825
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 131 | valid loss  5.21  4.60 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.04585814476013
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009405056834220887
s_total_loss1.item()/UPDATE_INTERVAL :  0.009423751831054688
w_total_loss0.item()/UPDATE_INTERVAL :  0.008619115352630616
w_total_loss1.item()/UPDATE_INTERVAL :  0.008756642341613769
| epoch 132 |     0/  184 batches | ms/batch  6.97 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.43093919754028
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 132 | valid loss  5.24  4.66 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.7748908996582
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011231983900070191
s_total_loss1.item()/UPDATE_INTERVAL :  0.011631382703781128
w_total_loss0.item()/UPDATE_INTERVAL :  0.008962604999542236
w_total_loss1.item()/UPDATE_INTERVAL :  0.009474369883537292
| epoch 133 |     0/  184 batches | ms/batch  7.00 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.83696007728577
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 133 | valid loss  5.23  4.59 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.21966314315796
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.00898551642894745
s_total_loss1.item()/UPDATE_INTERVAL :  0.009176318645477294
w_total_loss0.item()/UPDATE_INTERVAL :  0.00850935399532318
w_total_loss1.item()/UPDATE_INTERVAL :  0.008459510803222657
| epoch 134 |     0/  184 batches | ms/batch  6.92 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.52016830444336
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 134 | valid loss  5.21  4.57 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.68490552902222
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.0083768630027771
s_total_loss1.item()/UPDATE_INTERVAL :  0.008559377789497375
w_total_loss0.item()/UPDATE_INTERVAL :  0.007180877327919007
w_total_loss1.item()/UPDATE_INTERVAL :  0.007545568346977234
| epoch 135 |     0/  184 batches | ms/batch  6.90 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.57930898666382
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 135 | valid loss  5.27  4.70 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.8543303012848
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009140684604644775
s_total_loss1.item()/UPDATE_INTERVAL :  0.009305336475372315
w_total_loss0.item()/UPDATE_INTERVAL :  0.009043715596199035
w_total_loss1.item()/UPDATE_INTERVAL :  0.009159367680549622
| epoch 136 |     0/  184 batches | ms/batch  6.95 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  238.52569818496704
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  389.1913056373596
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 136 | valid loss  5.19  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  424.31283950805664
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.010123461484909058
s_total_loss1.item()/UPDATE_INTERVAL :  0.010199499130249024
w_total_loss0.item()/UPDATE_INTERVAL :  0.008383671641349793
w_total_loss1.item()/UPDATE_INTERVAL :  0.008722800612449646
| epoch 137 |     0/  184 batches | ms/batch  6.92 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.09303164482117
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 137 | valid loss  5.24  4.59 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.7601683139801
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011067887544631958
s_total_loss1.item()/UPDATE_INTERVAL :  0.01113924264907837
w_total_loss0.item()/UPDATE_INTERVAL :  0.011353191137313843
w_total_loss1.item()/UPDATE_INTERVAL :  0.011447099447250366
| epoch 138 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.58276844024658
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 138 | valid loss  5.24  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.70590114593506
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008802192807197571
s_total_loss1.item()/UPDATE_INTERVAL :  0.009020058512687683
w_total_loss0.item()/UPDATE_INTERVAL :  0.007618967890739441
w_total_loss1.item()/UPDATE_INTERVAL :  0.008567095398902894
| epoch 139 |     0/  184 batches | ms/batch  7.08 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.5212631225586
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 139 | valid loss  5.12  4.57 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.08029198646545
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008832432627677918
s_total_loss1.item()/UPDATE_INTERVAL :  0.00893796980381012
w_total_loss0.item()/UPDATE_INTERVAL :  0.007960515022277832
w_total_loss1.item()/UPDATE_INTERVAL :  0.008000035285949707
| epoch 140 |     0/  184 batches | ms/batch  6.93 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.30481696128845
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 140 | valid loss  5.16  4.59 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.4268159866333
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010882247686386109
s_total_loss1.item()/UPDATE_INTERVAL :  0.010810649394989014
w_total_loss0.item()/UPDATE_INTERVAL :  0.00975459098815918
w_total_loss1.item()/UPDATE_INTERVAL :  0.009720786213874818
| epoch 141 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.72593355178833
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 141 | valid loss  5.19  4.56 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.26643443107605
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009113690853118896
s_total_loss1.item()/UPDATE_INTERVAL :  0.009048648476600647
w_total_loss0.item()/UPDATE_INTERVAL :  0.008582388758659363
w_total_loss1.item()/UPDATE_INTERVAL :  0.008287227749824523
| epoch 142 |     0/  184 batches | ms/batch  6.69 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.02737140655518
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 142 | valid loss  5.23  4.68 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.13479804992676
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008931847214698791
s_total_loss1.item()/UPDATE_INTERVAL :  0.009154209494590759
w_total_loss0.item()/UPDATE_INTERVAL :  0.00792158305644989
w_total_loss1.item()/UPDATE_INTERVAL :  0.00821650207042694
| epoch 143 |     0/  184 batches | ms/batch  6.98 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.5471842288971
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 143 | valid loss  5.19  4.55 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.08492159843445
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.011224716901779175
s_total_loss1.item()/UPDATE_INTERVAL :  0.011433026790618896
w_total_loss0.item()/UPDATE_INTERVAL :  0.009635584354400635
w_total_loss1.item()/UPDATE_INTERVAL :  0.009828023910522461
| epoch 144 |     0/  184 batches | ms/batch  6.77 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  236.9518666267395
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  386.63393449783325
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 144 | valid loss  5.24  4.69 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  422.53762793540955
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.009295745491981507
s_total_loss1.item()/UPDATE_INTERVAL :  0.009571906924247742
w_total_loss0.item()/UPDATE_INTERVAL :  0.009336593747138976
w_total_loss1.item()/UPDATE_INTERVAL :  0.009580699801445007
| epoch 145 |     0/  184 batches | ms/batch  6.90 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.85639929771423
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 145 | valid loss  5.21  4.55 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.3003056049347
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010206092596054078
s_total_loss1.item()/UPDATE_INTERVAL :  0.010258232355117797
w_total_loss0.item()/UPDATE_INTERVAL :  0.008904698491096496
w_total_loss1.item()/UPDATE_INTERVAL :  0.008935559391975403
| epoch 146 |     0/  184 batches | ms/batch  6.86 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.17286562919617
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 146 | valid loss  5.16  4.61 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.53742003440857
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010825762748718262
s_total_loss1.item()/UPDATE_INTERVAL :  0.010934354066848754
w_total_loss0.item()/UPDATE_INTERVAL :  0.009586572647094727
w_total_loss1.item()/UPDATE_INTERVAL :  0.009735206961631776
| epoch 147 |     0/  184 batches | ms/batch  6.91 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.69974780082703
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 147 | valid loss  5.17  4.64 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.38808298110962
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009378662109375
s_total_loss1.item()/UPDATE_INTERVAL :  0.009327039122581482
w_total_loss0.item()/UPDATE_INTERVAL :  0.008406473994255067
w_total_loss1.item()/UPDATE_INTERVAL :  0.008516192436218262
| epoch 148 |     0/  184 batches | ms/batch  6.91 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.41781425476074
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 148 | valid loss  5.25  4.64 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.38723945617676
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010339452028274536
s_total_loss1.item()/UPDATE_INTERVAL :  0.010462250709533692
w_total_loss0.item()/UPDATE_INTERVAL :  0.009471194148063659
w_total_loss1.item()/UPDATE_INTERVAL :  0.009577602744102479
| epoch 149 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.82274436950684
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 149 | valid loss  5.16  4.54 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.64966344833374
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008358533382415772
s_total_loss1.item()/UPDATE_INTERVAL :  0.0082643461227417
w_total_loss0.item()/UPDATE_INTERVAL :  0.00740967333316803
w_total_loss1.item()/UPDATE_INTERVAL :  0.006892431378364563
| epoch 150 |     0/  184 batches | ms/batch  6.91 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.02001333236694
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 150 | valid loss  5.22  4.58 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.3561532497406
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010116287469863892
s_total_loss1.item()/UPDATE_INTERVAL :  0.01023560643196106
w_total_loss0.item()/UPDATE_INTERVAL :  0.009476292729377746
w_total_loss1.item()/UPDATE_INTERVAL :  0.009212243556976318
| epoch 151 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.59278178215027
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 151 | valid loss  5.22  4.66 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.69718623161316
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009000515937805176
s_total_loss1.item()/UPDATE_INTERVAL :  0.009082784056663512
w_total_loss0.item()/UPDATE_INTERVAL :  0.00804934024810791
w_total_loss1.item()/UPDATE_INTERVAL :  0.008133825659751893
| epoch 152 |     0/  184 batches | ms/batch  6.74 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  236.89403462409973
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  386.59476113319397
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 152 | valid loss  5.26  4.68 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  422.05337738990784
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.009440441131591797
s_total_loss1.item()/UPDATE_INTERVAL :  0.009484308362007142
w_total_loss0.item()/UPDATE_INTERVAL :  0.00832057774066925
w_total_loss1.item()/UPDATE_INTERVAL :  0.008492931723594666
| epoch 153 |     0/  184 batches | ms/batch  6.86 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.22431349754333
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 153 | valid loss  5.22  4.59 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.7529935836792
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009699516296386719
s_total_loss1.item()/UPDATE_INTERVAL :  0.009887158274650573
w_total_loss0.item()/UPDATE_INTERVAL :  0.008785271644592285
w_total_loss1.item()/UPDATE_INTERVAL :  0.008293423652648926
| epoch 154 |     0/  184 batches | ms/batch  7.02 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.34323811531067
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 154 | valid loss  5.26  4.63 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.8944308757782
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.007293133735656738
s_total_loss1.item()/UPDATE_INTERVAL :  0.007543371319770813
w_total_loss0.item()/UPDATE_INTERVAL :  0.006476684212684631
w_total_loss1.item()/UPDATE_INTERVAL :  0.006391221880912781
| epoch 155 |     0/  184 batches | ms/batch  6.97 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.64354753494263
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 155 | valid loss  5.21  4.63 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.27059268951416
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010208034515380859
s_total_loss1.item()/UPDATE_INTERVAL :  0.010278173685073853
w_total_loss0.item()/UPDATE_INTERVAL :  0.009909825325012207
w_total_loss1.item()/UPDATE_INTERVAL :  0.010278230905532837
| epoch 156 |     0/  184 batches | ms/batch  6.71 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.4279236793518
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 156 | valid loss  5.29  4.70 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.85357403755188
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009501439929008483
s_total_loss1.item()/UPDATE_INTERVAL :  0.009730391502380371
w_total_loss0.item()/UPDATE_INTERVAL :  0.008206944465637207
w_total_loss1.item()/UPDATE_INTERVAL :  0.00775820791721344
| epoch 157 |     0/  184 batches | ms/batch  6.70 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.8464651107788
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 157 | valid loss  5.12  4.58 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.53652143478394
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.010187643766403198
s_total_loss1.item()/UPDATE_INTERVAL :  0.010335983037948608
w_total_loss0.item()/UPDATE_INTERVAL :  0.009779425263404846
w_total_loss1.item()/UPDATE_INTERVAL :  0.010229824781417847
| epoch 158 |     0/  184 batches | ms/batch  6.80 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.36759519577026
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 158 | valid loss  5.19  4.62 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  174.6993706226349
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009750598073005677
s_total_loss1.item()/UPDATE_INTERVAL :  0.009810616374015807
w_total_loss0.item()/UPDATE_INTERVAL :  0.008000013828277587
w_total_loss1.item()/UPDATE_INTERVAL :  0.007846524119377135
| epoch 159 |     0/  184 batches | ms/batch  6.83 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.32895231246948
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 159 | valid loss  5.21  4.57 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.52389454841614
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008718544840812683
s_total_loss1.item()/UPDATE_INTERVAL :  0.00906795084476471
w_total_loss0.item()/UPDATE_INTERVAL :  0.007769754528999329
w_total_loss1.item()/UPDATE_INTERVAL :  0.008196452260017395
| epoch 160 |     0/  184 batches | ms/batch  6.73 | s_loss  0.01  0.01 | w_loss  0.01  0.01
bulding images
CURRENT WORKING DIRCTORY :  /content/AttnGAN/code
keyTime |||||||||||||||||||||||||||||||
build_super_images_time :  235.5716404914856
KeyTime |||||||||||||||||||||||||||||||
keyTime |||||||||||||||||||||||||||||||
train_function_time :  385.2588703632355
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 160 | valid loss  5.17  4.58 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  420.6606409549713
KeyTime |||||||||||||||||||||||||||||||
Save G/Ds models.
s_total_loss0.item()/UPDATE_INTERVAL :  0.010146347284317016
s_total_loss1.item()/UPDATE_INTERVAL :  0.010178186893463136
w_total_loss0.item()/UPDATE_INTERVAL :  0.00905631721019745
w_total_loss1.item()/UPDATE_INTERVAL :  0.00902872085571289
| epoch 161 |     0/  184 batches | ms/batch  6.94 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.77360105514526
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 161 | valid loss  5.19  4.68 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  176.33637499809265
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.007961161136627197
s_total_loss1.item()/UPDATE_INTERVAL :  0.007916080355644227
w_total_loss0.item()/UPDATE_INTERVAL :  0.007562993168830872
w_total_loss1.item()/UPDATE_INTERVAL :  0.007591751217842102
| epoch 162 |     0/  184 batches | ms/batch  6.77 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.46225118637085
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 162 | valid loss  5.26  4.59 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.80960059165955
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.008214089274406432
s_total_loss1.item()/UPDATE_INTERVAL :  0.008377504348754884
w_total_loss0.item()/UPDATE_INTERVAL :  0.007456968426704407
w_total_loss1.item()/UPDATE_INTERVAL :  0.007218237519264221
| epoch 163 |     0/  184 batches | ms/batch  6.90 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.8665726184845
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 163 | valid loss  5.10  4.49 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.88037657737732
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009829286932945252
s_total_loss1.item()/UPDATE_INTERVAL :  0.009924526810646057
w_total_loss0.item()/UPDATE_INTERVAL :  0.009252737164497376
w_total_loss1.item()/UPDATE_INTERVAL :  0.00906355917453766
| epoch 164 |     0/  184 batches | ms/batch  6.95 | s_loss  0.01  0.01 | w_loss  0.01  0.01
keyTime |||||||||||||||||||||||||||||||
train_function_time :  140.709331035614
KeyTime |||||||||||||||||||||||||||||||
-----------------------------------------------------------------------------------------
| end epoch 164 | valid loss  5.21  4.67 | lr 0.00020|
-----------------------------------------------------------------------------------------
keyTime |||||||||||||||||||||||||||||||
one_epoch_time :  175.94233536720276
KeyTime |||||||||||||||||||||||||||||||
s_total_loss0.item()/UPDATE_INTERVAL :  0.009154966473579407
s_total_loss1.item()/UPDATE_INTERVAL :  0.009160087704658508
w_total_loss0.item()/UPDATE_INTERVAL :  0.00735959529876709
w_total_loss1.item()/UPDATE_INTERVAL :  0.00750575065612793
| epoch 165 |     0/  184 batches | ms/batch  7.05 | s_loss  0.01  0.01 | w_loss  0.01  0.01

# %%
# !python pretrain_DAMSM.py --cfg cfg/DAMSM/bird.yml --gpu 0
